# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !apt-get install -y p7zip-full
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# p7zip-full is already the newest version (16.02+dfsg-8).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
zip_path = '/content/drive/MyDrive/Normalized_Dataset.7z'

import os

# Dossier de destination pour le dataset décompressé
dataset_dir = '/content/drive/MyDrive/unzip_dataset'
os.makedirs(dataset_dir, exist_ok=True)

# Extraire le fichier .7z
!7z x "$zip_path" -o"$dataset_dir"
print("Extraction terminée !")
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 69254382 bytes (67 MiB)
#
# Extracting archive: /content/drive/MyDrive/Normalized_Dataset.7z
# --
# Path = /content/drive/MyDrive/Normalized_Dataset.7z
# Type = 7z
# Physical Size = 69254382
# Headers Size = 66847
# Method = LZMA2:24
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 13
# Files: 6224
# Size:       73865443
# Compressed: 69254382
# Extraction terminée !
